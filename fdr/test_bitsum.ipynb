# %%
#  차트 설정
# %matplotlib inline
import matplotlib.pyplot as plt

plt.rcParams["figure.figsize"] = (14,4)
plt.rcParams['lines.linewidth'] = 2
plt.rcParams["axes.grid"] = True

# %%
# %%html
# <style>
#     table { display: inline-block }
#     .rendered_html td, .rendered_html th { text-align: left; }
# </style>
# Out:
# <style>
#     table { display: inline-block }
#     .rendered_html td, .rendered_html th { text-align: left; }
# </style>

# %%
import FinanceDataReader as fdr
fdr.__version__
# Out:
# '0.9.94'

# %%
import FinanceDataReader as fdr

# 원달러 환율, 1995년~현재
df_USD = fdr.DataReader('USD/KRW', '2024')
df_USD['Close'].plot()
# Out:
# <Axes: >

# %%
import FinanceDataReader as fdr

df_BTC = fdr.DataReader('BTC/KRW', '2024')
df_BTC['Close'].plot()
# Out:
# <Axes: >

# %%
df_ETH = fdr.DataReader('ETH/KRW', '2024')
df_ETH['Close'].plot()
# Out:
# <Axes: >

# %%
df_CFX = fdr.DataReader('CFX/KRW', '2024')
df_CFX['Close'].plot()
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 df_CFX = fdr.DataReader('CFX/KRW', '2024')
#       2 df_CFX['Close'].plot()
#
# File c:\X\_\Python310\lib\site-packages\FinanceDataReader\data.py:92, in DataReader(symbol, start, end, exchange, data_source)
#      88         return NaverDailyReader(codes, start, end).read()
#      89     # 1-4) US and other stocks
#      90     else:
#      91         # Yahoo is default source for US and other stocks
# ---> 92         return YahooDailyReader(codes, start, end).read()
#      94 else:  # data source specified
#      95     if source == 'KRX':
#
# File c:\X\_\Python310\lib\site-packages\FinanceDataReader\yahoo\data.py:61, in YahooDailyReader.read(self)
#      58 def read(self):
#      59     # single symbol
#      60     if ',' not in self.symbol:
# ---> 61         return _yahoo_data_reader(self.symbol, self.exchange, self.start, self.end)
#      63     # multiple symbols, merge close price data as columns
#      64     df_list = []
#
# File c:\X\_\Python310\lib\site-packages\FinanceDataReader\yahoo\data.py:38, in _yahoo_data_reader(symbol, exchange, start, end)
#      33 url = (
#      34     f'https://query2.finance.yahoo.com/v8/finance/chart/{_map_symbol(symbol, exchange)}?'
#      35     f'period1={start_ts}&period2={end_ts}&interval=1d&includeAdjustedClose=true'
#      36 )
#      37 r = requests.get(url, headers={'user-agent': 'Mozilla/5.0 AppleWebKit/537.36'})
# ---> 38 r.raise_for_status()
#      39 jo = r.json()
#      41 index = pd.to_datetime(jo['chart']['result'][0]['timestamp'], unit='s').normalize()
#
# File c:\X\_\Python310\lib\site-packages\requests\models.py:1021, in Response.raise_for_status(self)
#    1016     http_error_msg = (
#    1017         f"{self.status_code} Server Error: {reason} for url: {self.url}"
#    1018     )
#    1020 if http_error_msg:
# -> 1021     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v8/finance/chart/CFX/KRW?period1=1704034800&period2=1732023509&interval=1d&includeAdjustedClose=true
