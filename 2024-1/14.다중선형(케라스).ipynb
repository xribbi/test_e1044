# %%
1. 백문이불여일타
2. 코딩은 학습이아니라 연습이라.

# %%
import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data/test.csv', header=None)
df.columns = ['q1','q2','mid','final']
df

# %%
x_data = df.iloc[:, :-1].values
y_data = df.iloc[:, [-1]].values

# %%
x_data.shape
# Out:
# (25, 3)

# %%
# forward : hx = tf.matmul(x,w) +b
dense = Dense( units=1, input_dim=3) # w: 3x1 , b:1
dense( x_data ) #hx = tf.matmul(x,w) +b

# %%
w,b = dense.get_weights()

# %%
print( w)
print( b )
# Out:
# [[ 0.9216994 ]
#  [ 0.86310494]
#  [-0.12568116]]
# [0.]

# %%
dense = Dense( units=1, input_dim=3)
model = Sequential( [dense] )
model.compile( loss='mse', optimizer=Adam(0.1))
h = model.fit( x_data, y_data, epochs=500)

# %%
w,b = dense.get_weights()
print( w)
print( b )

# %%
#dense( x_data )
pred = model.predict( x_data )
# Out:
# 1/1 [==============================] - 0s 22ms/step

# %%
plt.plot( y_data )
plt.plot( pred ,'r--')
plt.show()

# %%
1. 상관관계(단일,다중)
2. 정규화(다중)
3. 다중공선성

# %%
# !pip install seaborn

# %%
import seaborn as sb

# %%
iris = sb.load_dataset('iris')
iris

# %%
10분퀴즈
------------------------------------
# 특성데이터: sepal_length,	sepal_width	, petal_length
# 라벨: petal_width

# %%
# 케라스로 학습후
sl:6.2	sw:3.4	pl: 5.4
pw 를 예측하시요.

# %%
x_data = iris.iloc[:,0:3].values
y_data = iris.iloc[:,[3]].values

# %%
dense = Dense( units=1, input_dim=3)
model = Sequential( [dense] )
model.compile( loss='mse', optimizer=Adam(0.1))
h = model.fit( x_data, y_data, epochs=500)

# %%
model.predict( [[6.2,3.4,5.4]])
# Out:
# 1/1 [==============================] - 0s 56ms/step
# array([[2.108209]], dtype=float32)

# %%
plt.plot( h.history['loss'])
plt.show()
